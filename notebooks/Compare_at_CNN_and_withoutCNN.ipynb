# %%
import random
random.seed(123)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.base import BaseEstimator, RegressorMixin, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import MinMaxScaler
import math
import time
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large'}
pylab.rcParams.update(params)
import scipy.stats as stats

# %%
sns.set_style("whitegrid")
#sns.set_palette('Set1')

# %%
data_folder = "../resources/data/discords/Earthquake3/"

# %%
df_overWorld = pd.read_csv(data_folder+"FromJsontoRawstream_ANEWeaarthquake2_Pre_CNN_Accumulate10secondsPredBOTH_overWorld.csv",header=None,names=['col0','col1','col2'],sep=",")
df_KoreaBoth = pd.read_csv(data_folder+"FromJsontoRawstream_ANEWeaarthquake2_Pre_CNN_Accumulate10secondsPredBOTH_romania.csv",header=None,names=['col0','col1','col2'],sep=",")
df_KoreaZero = pd.read_csv(data_folder+"FromJsontoRawstream_ANEWeaarthquake2_Pre_CNN_Accumulate10secondsPredZERO_romania.csv",header=None,names=['col0','col1','col2'],sep=",")
df_KoreaOne = pd.read_csv(data_folder+"FromJsontoRawstream_ANEWeaarthquake2_Pre_CNN_Accumulate10secondsPredONE_romania.csv",header=None,names=['col0','col1','col2'],sep=",")

# %%
df_overWorld.drop('col0', axis=1, inplace=True)
df_overWorld.drop('col1', axis=1, inplace=True)

df_KoreaBoth.drop('col0', axis=1, inplace=True)
df_KoreaBoth.drop('col1', axis=1, inplace=True)

df_KoreaZero.drop('col0', axis=1, inplace=True)
df_KoreaZero.drop('col1', axis=1, inplace=True)

df_KoreaOne.drop('col0', axis=1, inplace=True)
df_KoreaOne.drop('col1', axis=1, inplace=True)

# %%
fig_Compare = plt.figure(figsize=(25,10))

#plt.subplot(411)
plt.ylim([0, 20])
#plt.plot(df_overWorld['col2'], label= 'overWorld')
plt.subplot(211)
plt.plot(df_KoreaBoth['col2'], label= 'at Rominia')
plt.subplot(212)
plt.plot(df_KoreaZero['col2'], label= 'informative')
#plt.subplot(414)
#plt.plot(df_KoreaOne['col2'], label= 'non-informative')
plt.legend()
plt.show()
pdf_compare=PdfPages("Preprocessing stage 2")
pdf_compare.savefig(fig_Compare)
pdf_compare.close()

# %%
data_folder = "../resources/data/discords/Earthquake/"

# %%
df_overWorld = pd.read_csv(data_folder+"FromJsontoRawearthquake21Sep_Pre _CNN_Accumulate10secondsPredBOTH_overWorld.csv",header=None,names=['col0','col1','col2'],sep=",")
df_KoreaBoth = pd.read_csv(data_folder+"FromJsontoRawstream_earthquake8_Pre_CNN_Accumulate10secondsPredBOTH_Ori_korea.csv",header=None,names=['col0','col1','col2'],sep=",")
df_KoreaZero = pd.read_csv(data_folder+"FromJsontoRawstream_earthquake8_Pre_CNN_Accumulate10secondsPredZERO_Ori_korea.csv",header=None,names=['col0','col1','col2'],sep=",")

# %%
df_overWorld.drop('col0', axis=1, inplace=True)
df_overWorld.drop('col1', axis=1, inplace=True)

df_KoreaBoth.drop('col0', axis=1, inplace=True)
df_KoreaBoth.drop('col1', axis=1, inplace=True)

df_KoreaZero.drop('col0', axis=1, inplace=True)
df_KoreaZero.drop('col1', axis=1, inplace=True)

# %%
fig_Compare = plt.figure(figsize=(25,10))

#plt.subplot(411)
plt.ylim([0, 10])
#plt.plot(df_overWorld['col2'], label= 'overWorld')
#plt.subplot(211)
plt.plot(df_KoreaBoth['col2'], label= 'without CNN')
#plt.subplot(212)
plt.plot(df_KoreaZero['col2'], label= 'informative')
#plt.subplot(414)
#plt.plot(df_KoreaOne['col2'], label= 'non-informative')
plt.legend()
plt.show()
pdf_compare=PdfPages("Preprocessing stage 2sss")
pdf_compare.savefig(fig_Compare)
pdf_compare.close()

# %%
data_folder = "../resources/data/discords/Earthquake5/"

# %%
df_overWorld = pd.read_csv(data_folder+"FromJsontoRawstream_ANEWeaarthquake2_Pre_CNN_Accumulate10secondsPredBOTH_overWorld.csv",header=None,names=['col0','col1','col2'],sep=",")
df_japanBoth = pd.read_csv(data_folder+"FromJsontoRawstream_ANEWeaarthquake2_Pre_CNN_Accumulate10secondsPredBOTH_japan.csv",header=None,names=['col0','col1','col2'],sep=",")
df_japanZero = pd.read_csv(data_folder+"FromJsontoRawstream_ANEWeaarthquake2_Pre_CNN_Accumulate10secondsPredZERO_japan.csv",header=None,names=['col0','col1','col2'],sep=",")
df_japanOne = pd.read_csv(data_folder+"FromJsontoRawstream_ANEWeaarthquake2_Pre_CNN_Accumulate10secondsPredONE_japan.csv",header=None,names=['col0','col1','col2'],sep=",")

# %%
df_overWorld.drop('col0', axis=1, inplace=True)
df_overWorld.drop('col1', axis=1, inplace=True)

df_japanBoth.drop('col0', axis=1, inplace=True)
df_japanBoth.drop('col1', axis=1, inplace=True)

df_japanZero.drop('col0', axis=1, inplace=True)
df_japanZero.drop('col1', axis=1, inplace=True)

df_japanOne.drop('col0', axis=1, inplace=True)
df_japanOne.drop('col1', axis=1, inplace=True)

# %%
fig_Compare = plt.figure(figsize=(25,5))

#plt.subplot(411)
#plt.ylim([0, 10])
plt.xlim([18000, 19000])
#plt.plot(df_overWorld['col2'], label= 'overWorld')
#plt.subplot(211)
plt.plot(df_japanBoth['col2'], label= 'without CNN')
#plt.subplot(212)
plt.plot(df_japanZero['col2'], label= 'informative')
#plt.subplot(414)
#plt.plot(df_japanOne['col2'], label= 'non-informative')
plt.legend()
plt.show()
pdf_compare=PdfPages("Preprocessing stage japan")
pdf_compare.savefig(fig_Compare)
pdf_compare.close()

# %%
df_overWorld = pd.read_csv(data_folder+"FromJsontoRawstream_ANEWeaarthquake2_Pre_CNN_Accumulate10secondsPredBOTH_overWorld.csv",header=None,names=['col0','col1','col2'],sep=",")
df_japan_daigoBoth = pd.read_csv(data_folder+"FromJsontoRawstream_ANEWeaarthquake2_Pre_CNN_Accumulate10secondsPredBOTH_daigo_japan.csv",header=None,names=['col0','col1','col2'],sep=",")
df_japan_daigoZero = pd.read_csv(data_folder+"FromJsontoRawstream_ANEWeaarthquake2_Pre_CNN_Accumulate10secondsPredZERO_daigo_japan.csv",header=None,names=['col0','col1','col2'],sep=",")
df_japan_daigoOne = pd.read_csv(data_folder+"FromJsontoRawstream_ANEWeaarthquake2_Pre_CNN_Accumulate10secondsPredONE_daigo_japan.csv",header=None,names=['col0','col1','col2'],sep=",")

# %%
df_overWorld.drop('col0', axis=1, inplace=True)
df_overWorld.drop('col1', axis=1, inplace=True)

df_japan_daigoBoth.drop('col0', axis=1, inplace=True)
df_japan_daigoBoth.drop('col1', axis=1, inplace=True)

df_japan_daigoZero.drop('col0', axis=1, inplace=True)
df_japan_daigoZero.drop('col1', axis=1, inplace=True)

df_japan_daigoOne.drop('col0', axis=1, inplace=True)
df_japan_daigoOne.drop('col1', axis=1, inplace=True)

# %%
fig_Compare = plt.figure(figsize=(25,5))

#plt.subplot(411)
plt.ylim([0, 10])
plt.xlim([10000, 20000])
#plt.plot(df_overWorld['col2'], label= 'overWorld')
#plt.subplot(211)
plt.plot(df_japan_daigoBoth['col2'], label= 'at Japan')
#plt.subplot(212)
plt.plot(df_japan_daigoZero['col2'], label= 'informative')
#plt.subplot(414)
#plt.plot(df_japan_daiOne['col2'], label= 'non-informative')
plt.legend()
plt.show()
pdf_compare=PdfPages("Preprocessing stage japan_daigo")
pdf_compare.savefig(fig_Compare)
pdf_compare.close()
